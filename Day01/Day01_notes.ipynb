# %% [markdown]
# <a href="https://colab.research.google.com/github/ManpreetRoy/Python-data-science-journey/blob/main/Day01/Day01_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Why Python ?
# 1. Design philosophy
# 2. Batteries Included
# 3. Genral purpose prog. lang
# 4. Lib/ community
#
# ## Why python for D. science ?
# 1. Easy to learn
# 2. Proximity with math, ex: Numpy , pandas
# 3. Community
#
# ### Q. Python is slow ?
# sol: We include Numpy lib , Numpy lib made in c++
#
# ### R vs Python
# R used in acedmic lang. better for graph and plot and python used in real world
#
#
# # Day 01 – Python Basics
# Today I learned:
# - How to print
# - Variables
# - Data types

# %%
#Python is case sensitive language
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
print('Hello, Manpreet')
# Out:
# Hello, Manpreet

# %%
print(7.8)
# Out:
# 7.8

# %%
print("Hello",2,6.2,True)
# Out:
# Hello 2 6.2 True

# %%
print("Hello",3,True,sep=' | ')
# Out:
# Hello | 3 | True

# %%
print('Data',end="-")
print("Science")
# Out:
# Data-Science

# %% [markdown]
# ## 2. Data Types
#    - Integer (Python can handle( 1e309 number = 1 * 10^308))
#    - Decimal / Float (1.7e308)
#    - Boolean ('True / False') **always used in ' '**
#    - Text / String always **used in " "**
#    - Complex = Print(5 + 6j) real and img
#    - List = Array , print ([ 1, 2, 3, 4, 5, 6]) using []
#    - Tuple , print((1,2,3,4,5,6)) using ()
#    - Sets , print({1,2,3,4,5,6}) using {}
#    - Dictionary : value in pairs , print({'name':'Akash','gender':'Male',weight':67})  using {}
